# %% [markdown]
# PRÁCTICA 2 EJERCICIO 1:

# %%
import plotly.express as px
from plotnine.data import mpg
import plotly.graph_objects as go
import pandas as pd

gb = mpg.groupby(["model"])[["cty", "hwy"]].agg("mean").reset_index().sort_values('cty', ascending=True) #Agrupa y condensa

fig = go.Figure()
fig.add_trace(go.Scatter(x=, y=, mode=, marker=, name = ))
fig.add_trace(go.Scatter())
for index, row in gb.iterrows():
  fig.add_shape(
          type="line",
          # connect the two markers
        
         y0=, x0=,
         
         y1=, x1=,
         line=
        )
fig.update_layout(xaxis_title=)
fig.show()

# %% [markdown]
# PRÁCTICA 2 EJERCICIO 2:

# %%
df = pd.read_csv("MSFT.csv")

# Create figure
fig = go.Figure()

fig.add_trace(
    go.Scatter())

# Set title
fig.update_layout(
    title=dict())

# Add range slider
fig.update_layout(
    xaxis=dict(
        rangeslider=dict(
            visible=True
        ),
        type="date"
    )
)

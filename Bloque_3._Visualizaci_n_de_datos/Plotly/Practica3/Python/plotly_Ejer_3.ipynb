# %%
import plotly.express as px
from plotnine.data import mpg
import plotly.graph_objects as go
import pandas as pd
import json

# %%
df = pd.read_csv() #Lee el fichero de sanciones

cp = pd.read_csv() #Lee el fichero de códigos postales

dfc = pd.merge() #Haz un merge de los dos ficheros (inner join)

with open('/content/spain-provinces.geojson') as response: #Lee el fichero json con los datos del mapa
    counties = json.load(response)

# %%
fig=px.choropleth(...., #dataframe completo con los datos 
             geojson=...., #fichero json con los datos del mapa
             featureidkey='properties.cartodb_id',   #property el el fichero json
             locations=....,        #columna con los datos que "lincarán" con la propiedad del mapa
              color=...,  #dato del dataframe que se asocia con el color del mapa
               title=.... , #título del mapa
                hover_data = [...], #datos que se muestran al pasar el ratón por encima
               height=700
              )
fig.update_geos(fitbounds="locations", visible=False) #para no mostrar el mapa general que choropleth pone por defecto
fig.update_layout(coloraxis_showscale=False) #para no mostrar la escala de colores
fig.show()

# %%
fig=px.choropleth(.....
              )
fig.update_geos(fitbounds="locations", visible=False)
fig.show()

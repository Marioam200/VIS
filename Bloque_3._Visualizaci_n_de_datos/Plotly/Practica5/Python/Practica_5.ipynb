# %% [markdown]
# PRÁCTICA 5 PREPARACIÓN:

# %%
from numpy.core.fromnumeric import mean
import plotly.express as px
from plotnine.data import mpg
import plotly.graph_objects as go
import pandas as pd

countries = pd.read_csv("countries.csv")

countries["mean_import"] = 200
countries["mean_export"] = 500
countries["year"] = pd.to_numeric(countries["year"])
countries = countries.sort_values("year")

# %% [markdown]
# PRÁCTICA 5 EJERCICIO 1:

# %%
fc = countries[....



fig.show()

# %% [markdown]
# PRÁCTICA 5 EJERCICIO 2:

# %%
fig1 = ....


fig1.show()

# %% [markdown]
# PRÁCTICA 5 EJERCICIO 3:

# %%
cs = countries[countries["region"] == "Europe & Central Asia"]
uc = sorted(cs.country.unique())

# Base plot
fig3 = go.Figure(
    layout=go.Layout(
        updatemenus=[dict(type="buttons", direction="right", x=0.9, y=1.16), ],
        xaxis=dict(range=[1998, 2020],
                   autorange=False, tickwidth=2,
                   title_text="Year"),
        yaxis=dict(range=[0, 250],
                   autorange=False,
                   title_text="Import"),
    ))

# Add traces
init = 1

init =1
for i in uc:
    css = countries[countries["country"] == i]

    fig3.add_trace(
        go.Scatter(.....................))

# Animation
framesf = []
for j in range(1998,2020):
    dataf = []
    for i in uc:
        css = countries[countries["country"] == i]
        csss = css[css.year <= j]

        dataf.append(go.Scatter(.................))
    framesf.append(go.Frame(.............))

fig3.update(...................)

# Buttons
fig3.update_layout(
    updatemenus=[
        dict(
            buttons=list([
                dict(label="Play",
                        method="animate",
                    args=[None, {"frame": {"duration": 1000}}]),
            ]))])
    
fig3.show()

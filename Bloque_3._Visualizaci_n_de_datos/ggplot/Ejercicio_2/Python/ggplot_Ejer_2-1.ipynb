# %% [markdown]
# PRÁCTICA 2 EJERCICIO 1:

# %%
from plotnine import *
import pandas as pd
import numpy as np
# !pip install scikit-misc

outcome = pd.read_csv("outcome-of-care-measures.csv")

column10 = outcome.columns[10]

outcome[column10] = pd.to_numeric(outcome[column10], errors="coerce")

print(outcome[column10].min())
print(outcome[column10].max())

p = ggplot()
p + geom_XXX() + geom_XXX() + xlab() + ggtitle() + scale_x_continuous(limits = (10,20))

# %% [markdown]
# PRÁCTICA 2 EJERCICIO 2:

# %%
outcomesel = outcome[outcome.columns[[10,16,22]]]
outcomesel.columns = ["Heart_Attack", "Heart_Failure", "Pneumonia"]
outcomesel["Heart_Failure"] = pd.to_numeric(outcomesel["Heart_Failure"], errors="coerce")
outcomesel["Pneumonia"] = pd.to_numeric(outcomesel["Pneumonia"], errors="coerce")

# melt() outcomesel

p = ggplot()
p1 = p + geom_XXX() + scale_x_continuous(limits = (5,20)) + ...

p1

# %% [markdown]
# PRÁCTICA 2 EJERCICIO 3:

# %%
t = outcome.State.value_counts()
a = t[outcome["State"]] > 20
outcome2 = outcome[a.values]
outcome3 = outcome2[outcome2[column10] != "Not Available"]

p = ggplot()
p =p+geom_XXX()
p = p + ... + theme(axis_text_x = element_text(angle=90))
print(p)

# Visita https://saturncloud.io/blog/how-to-sort-a-boxplot-in-pandas-by-median-values/ para ordenar los estados por mediana

p1 = ggplot() + geom_XXX() + scale_x_discrete(limits=sal)
p1 = p1 + ... + theme(axis_text_x = element_text(angle=90))
print(p1)

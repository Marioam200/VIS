# %% [markdown]
# PRÁCTICA 1 EJERCICIO 1:

# %%
from plotnine import *
import pandas as pd
# !pip install scikit-misc

QTC = pd.read_csv("")

p = ggplot() + geom_XXX() #Hay que sustituir XXX por el tipo de gráfico que queremos

print(p+geom_XXX())
print(p+geom_XXX())

# %% [markdown]
# PRÁCTICA 1 EJERCICIO 2:

# %%
p = ggplot() + geom_XXX() + ggtitle("Relación K1 y K2") + theme(title = element_text(hjust = 0.5))
p+geom_

# %% [markdown]
# PRÁCTICA 1 EJERCICIO 3:

# %%
p = ggplot() + ....
p

# %% [markdown]
# PRÁCTICA 1 EJERCICIO 4:

# %%
p = ggplot() + geom_bar()
p

# %% [markdown]
# PRÁCTICA 1 EJERCICIO 5:

# %%
p = ggplot() + geom_XXX() + facet_grid("diam~na")
p

# %%
PRÁCTICA 1 EJERCICIO 6:

# %%
p1 = ggplot() + geom_boxplot()
p2 = ggplot() + geom_boxplot()
print(p1)
print(p2)
